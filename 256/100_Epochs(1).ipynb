# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import sys
import time
import cv2
import numpy as np
from matplotlib import pyplot as plt
import os

from skimage.transform import resize
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.applications import ResNet50
sys.version
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# '3.6.9 (default, Nov  7 2019, 10:44:02) \n[GCC 8.3.0]'

# %%
# !unzip -q "drive/My Drive/test fish/Dataset.zip"

# %%
categori = os.listdir(os.path.join(os.getcwd(),"Dataset"))

# %%
base_path = "Dataset"
categories = sorted(categori)

# %%
print(categories)
# Out:
# ['Angler Frog', 'Anthias', 'Banggai Cardinal', 'Baracuda', 'Barred Thicklip', 'Bawal', 'Belanak', 'Bibir Merah', 'Black Saddled Toby', 'Blackbar Soldierfish', 'Blackbar chromis', 'Blackghost', 'Blue Devil', 'Brown Tangfish', 'Buntal', 'Chelmon Rostratus', 'Chevron Butterflyfish', 'Dottyback', 'Foureye Butterflyfish', 'Giru (Nemo)', 'Hiu Paus', 'Hiu Putih', 'Indigo Hamlet', 'Julung-Julung', 'Kakaktua', 'Kakap-Merah', 'Kerapu', 'King Anglefish', 'Kuwe Gerong', 'Layur', 'Lemadeng', 'Lemon', 'Lepu Ayam', 'Lumba-Lumba', 'Mandarin', 'Marlin', 'Moorish Idol', 'Napoleon', 'Neoniphon Sammara', 'Oval Butterflyfish', 'Pari', 'Paus Pembunuh', 'Paus Sirip', 'Rainbow', 'Terbang', 'Triggerfish', 'Tuna', 'Vanikoro Sweeper', 'Yellow Tangfish', 'Yellow Watchman Godies']

# %%
fnames = []
for category in categories:
    fish_folder = os.path.join(base_path, category)
    file_names = os.listdir(fish_folder)
    full_path = [os.path.join(fish_folder, file_name) for file_name in file_names]
    fnames.append(full_path)

# %%
images = []
for names in fnames:
    one_category_images = [cv2.imread(name) for name in names if (cv2.imread(name)) is not None]
    images.append(one_category_images)

# %%
print('Jumlah Gambar Setiap Kategori:', [len(f) for f in images])
# Out:
# Jumlah Gambar Setiap Kategori: [50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50]

# %%
for i,imgs in enumerate(images):
    shapes = [img.shape for img in imgs]
    widths = [shape[0] for shape in shapes]
    heights = [shape[1] for shape in shapes]
    print('%d,%d is the min shape for %s' % (np.min(widths), np.min(heights), categories[i]))
# Out:
# 169,220 is the min shape for Angler Frog
# 168,224 is the min shape for Anthias
# 146,220 is the min shape for Banggai Cardinal
# 129,200 is the min shape for Baracuda
# 77,75 is the min shape for Barred Thicklip
# 156,160 is the min shape for Bawal
# 124,275 is the min shape for Belanak
# 183,275 is the min shape for Bibir Merah
# 66,68 is the min shape for Black Saddled Toby
# 129,200 is the min shape for Blackbar Soldierfish
# 183,208 is the min shape for Blackbar chromis
# 163,250 is the min shape for Blackghost
# 160,295 is the min shape for Blue Devil
# 62,71 is the min shape for Brown Tangfish
# 184,236 is the min shape for Buntal
# 183,242 is the min shape for Chelmon Rostratus
# 120,200 is the min shape for Chevron Butterflyfish
# 145,211 is the min shape for Dottyback
# 157,168 is the min shape for Foureye Butterflyfish
# 182,183 is the min shape for Giru (Nemo)
# 229,350 is the min shape for Hiu Paus
# 165,200 is the min shape for Hiu Putih
# 140,211 is the min shape for Indigo Hamlet
# 176,259 is the min shape for Julung-Julung
# 153,200 is the min shape for Kakaktua
# 133,220 is the min shape for Kakap-Merah
# 135,200 is the min shape for Kerapu
# 180,225 is the min shape for King Anglefish
# 120,211 is the min shape for Kuwe Gerong
# 105,211 is the min shape for Layur
# 147,225 is the min shape for Lemadeng
# 155,220 is the min shape for Lemon
# 132,200 is the min shape for Lepu Ayam
# 177,265 is the min shape for Lumba-Lumba
# 160,240 is the min shape for Mandarin
# 136,227 is the min shape for Marlin
# 206,190 is the min shape for Moorish Idol
# 165,220 is the min shape for Napoleon
# 225,225 is the min shape for Neoniphon Sammara
# 154,211 is the min shape for Oval Butterflyfish
# 150,218 is the min shape for Pari
# 149,220 is the min shape for Paus Pembunuh
# 183,250 is the min shape for Paus Sirip
# 143,183 is the min shape for Rainbow
# 231,218 is the min shape for Terbang
# 165,220 is the min shape for Triggerfish
# 134,250 is the min shape for Tuna
# 88,95 is the min shape for Vanikoro Sweeper
# 160,197 is the min shape for Yellow Tangfish
# 168,183 is the min shape for Yellow Watchman Godies

# %%
def cvtRGB(img):
    return cv2.cvtColor(img.copy(), cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(15,10))
for i, imgs in enumerate(images):
    plt.subplot(10,6,i+1)
    idx = np.random.randint(len(imgs))
    plt.imshow(cvtRGB(imgs[idx]))
    plt.grid('off')
    plt.title(categories[i]+' '+str(idx))
plt.show()

# %%
img_width, img_height = 256, 256

img = images[2][2]
print(img.shape)
resized_img = resize(img, (img_width, img_height, 3))
resized_img2 = cv2.resize(img,(img_width, img_height), interpolation = cv2.INTER_CUBIC)
print(resized_img.shape)
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
plt.title('original image (BGR-channel)')
plt.grid(False)
plt.imshow(img)
plt.subplot(2,2,2)
plt.title('original image (RGB-channel)')
plt.grid(False)
plt.imshow(cvtRGB(img))
plt.subplot(2,2,3)
plt.title('resized by skimage (BGR-channel)')
plt.grid(False)
plt.imshow((resized_img))
plt.subplot(2,2,4)
plt.title('resized by opencv (RGB-channel)')
plt.grid(False)
plt.imshow(cvtRGB(resized_img2))
plt.show()
# Out:
# (600, 896, 3)
# (256, 256, 3)

# %%
resized_images = []
for i,imgs in enumerate(images):
    resized_images.append([cv2.resize(img, (img_width, img_height), interpolation = cv2.INTER_CUBIC) for img in imgs])

# %%
train_images = []
val_images = []
for imgs in resized_images:
    train, test = train_test_split(imgs, train_size=0.8, test_size=0.2)
    train_images.append(train)
    val_images.append(test)

# %%
len_train_images = [len(imgs) for imgs in train_images]
print(len_train_images)
print('Jumlah Total Data Training:', np.sum(len_train_images))
train_categories = np.zeros((np.sum(len_train_images)), dtype='uint8')
for i in range(50):
    if i is 0:
        train_categories[:len_train_images[i]] = i
    else:
        train_categories[np.sum(len_train_images[:i]):np.sum(len_train_images[:i+1])] = i
        
len_val_images = [len(imgs) for imgs in val_images]
print(len_val_images)
print('Jumlah Total Data Validation:', np.sum(len_val_images))
val_categories = np.zeros((np.sum(len_val_images)), dtype='uint8')
for i in range(50):
    if i is 0:
        val_categories[:len_val_images[i]] = i
    else:
        val_categories[np.sum(len_val_images[:i]):np.sum(len_val_images[:i+1])] = i
# Out:
# [40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40]
# Jumlah Total Data Training: 2000
# [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10]
# Jumlah Total Data Validation: 500

# %%
tmp_train_imgs = []
tmp_val_imgs = []
for imgs in train_images:
    tmp_train_imgs += imgs
for imgs in val_images:
    tmp_val_imgs += imgs
train_images = np.array(tmp_train_imgs)
val_images = np.array(tmp_val_imgs)

# %%
print('Before converting')
print('train data:', train_images.shape)
print('train labels:', train_categories.shape)

train_data = train_images.astype('float32')
val_data = val_images.astype('float32')
train_labels = to_categorical(train_categories, len(categories))
val_labels = to_categorical(val_categories, len(categories))
print()
print('After converting')
print('train data:', train_data.shape)
print('train labels:', train_labels.shape)
# Out:
# Before converting
# train data: (2000, 256, 256, 3)
# train labels: (2000,)
#
# After converting
# train data: (2000, 256, 256, 3)
# train labels: (2000, 50)

# %%
train_data = train_data[:2000]
train_labels = train_labels[:2000]
val_data = val_data[:500]
val_labels = val_labels[:500]
print('shape of train data:', train_data.shape)
print('shape of train labels:', train_labels.shape)
print('shape of val data:', val_data.shape)
print('shape of val labels:', val_labels.shape)
# Out:
# shape of train data: (2000, 256, 256, 3)
# shape of train labels: (2000, 50)
# shape of val data: (500, 256, 256, 3)
# shape of val labels: (500, 50)

# %%
def create_model_from_ResNet50():

    model = Sequential()
    model.add(ResNet50(include_top=False, pooling='avg', weights='imagenet', input_tensor=None, input_shape=(256, 256, 3)))
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(BatchNormalization())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(BatchNormalization())
    model.add(Dense(len(categories), activation='softmax'))

    optimizer = Adam(learning_rate=0.0001)
    
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
    
    return model

# %%
model_ResNet50 = create_model_from_ResNet50()
model_ResNet50.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                25650
# =================================================================
# Total params: 24,672,690
# Trainable params: 24,614,450
# Non-trainable params: 58,240
# _________________________________________________________________

# %%
batch_size = 32
epochs = 100

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    width_shift_range=0.4,
    height_shift_range=0.4,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(
    rescale=1./255,
)


train_generator = train_datagen.flow(
    train_data,
    train_labels,
    batch_size=batch_size
)

val_generator = val_datagen.flow(
    val_data,
    val_labels,
    batch_size=batch_size
)

# %%
start = time.time()

model_ResNet50_info = model_ResNet50.fit_generator(
    generator=train_generator, 
    steps_per_epoch=len(train_data)/batch_size, 
    epochs=epochs, 
    validation_steps=len(val_data)/batch_size,
    validation_data=val_generator, 
    verbose=2
)

end = time.time()
duration = end - start
print ('\n model_ResNet50 Memerlukan Waktu %0.2f Detik (%0.1f Menit) Dengan Menggunakan %d Epochs'%(duration, duration/60, epochs) )
# Out:
# Epoch 1/100
# Epoch 1/100
# 63/62 - 50s - loss: 4.1326 - acc: 0.0740 - val_loss: 4.7327 - val_acc: 0.0200
# Epoch 2/100
# Epoch 1/100
# 63/62 - 30s - loss: 2.7142 - acc: 0.3055 - val_loss: 4.7133 - val_acc: 0.0200
# Epoch 3/100
# Epoch 1/100
# 63/62 - 31s - loss: 1.6685 - acc: 0.5785 - val_loss: 4.4174 - val_acc: 0.0140
# Epoch 4/100
# Epoch 1/100
# 63/62 - 31s - loss: 1.0717 - acc: 0.7575 - val_loss: 4.3205 - val_acc: 0.0260
# Epoch 5/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.7575 - acc: 0.8380 - val_loss: 4.2041 - val_acc: 0.0360
# Epoch 6/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.5710 - acc: 0.8760 - val_loss: 4.1573 - val_acc: 0.0580
# Epoch 7/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.4011 - acc: 0.9220 - val_loss: 4.0023 - val_acc: 0.0920
# Epoch 8/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.3205 - acc: 0.9420 - val_loss: 3.6553 - val_acc: 0.1500
# Epoch 9/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.2600 - acc: 0.9485 - val_loss: 3.3758 - val_acc: 0.2300
# Epoch 10/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.2359 - acc: 0.9540 - val_loss: 2.5828 - val_acc: 0.3600
# Epoch 11/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1787 - acc: 0.9680 - val_loss: 1.9269 - val_acc: 0.5420
# Epoch 12/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1744 - acc: 0.9695 - val_loss: 1.1935 - val_acc: 0.7100
# Epoch 13/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1438 - acc: 0.9740 - val_loss: 0.8674 - val_acc: 0.7760
# Epoch 14/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1777 - acc: 0.9655 - val_loss: 0.7325 - val_acc: 0.8160
# Epoch 15/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1237 - acc: 0.9790 - val_loss: 0.5662 - val_acc: 0.8880
# Epoch 16/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1269 - acc: 0.9735 - val_loss: 0.4290 - val_acc: 0.8920
# Epoch 17/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1009 - acc: 0.9820 - val_loss: 0.3601 - val_acc: 0.9320
# Epoch 18/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1253 - acc: 0.9745 - val_loss: 0.3010 - val_acc: 0.9320
# Epoch 19/100
# Epoch 1/100
# 63/62 - 30s - loss: 0.1056 - acc: 0.9775 - val_loss: 0.3424 - val_acc: 0.9200
# Epoch 20/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1046 - acc: 0.9775 - val_loss: 0.2957 - val_acc: 0.9260
# Epoch 21/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0799 - acc: 0.9875 - val_loss: 0.3055 - val_acc: 0.9280
# Epoch 22/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0759 - acc: 0.9850 - val_loss: 0.2842 - val_acc: 0.9280
# Epoch 23/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0736 - acc: 0.9815 - val_loss: 0.3448 - val_acc: 0.9120
# Epoch 24/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0675 - acc: 0.9865 - val_loss: 0.3251 - val_acc: 0.9240
# Epoch 25/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0979 - acc: 0.9795 - val_loss: 0.3763 - val_acc: 0.9180
# Epoch 26/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0943 - acc: 0.9790 - val_loss: 0.3217 - val_acc: 0.9220
# Epoch 27/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0937 - acc: 0.9800 - val_loss: 0.3826 - val_acc: 0.9200
# Epoch 28/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1039 - acc: 0.9765 - val_loss: 0.4969 - val_acc: 0.8880
# Epoch 29/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0973 - acc: 0.9790 - val_loss: 0.3721 - val_acc: 0.9120
# Epoch 30/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1127 - acc: 0.9755 - val_loss: 0.3792 - val_acc: 0.9120
# Epoch 31/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1000 - acc: 0.9760 - val_loss: 0.2827 - val_acc: 0.9260
# Epoch 32/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1059 - acc: 0.9740 - val_loss: 0.2458 - val_acc: 0.9360
# Epoch 33/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.1063 - acc: 0.9750 - val_loss: 0.4182 - val_acc: 0.9120
# Epoch 34/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0663 - acc: 0.9850 - val_loss: 0.2576 - val_acc: 0.9280
# Epoch 35/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0617 - acc: 0.9825 - val_loss: 0.3937 - val_acc: 0.9120
# Epoch 36/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0755 - acc: 0.9835 - val_loss: 0.3478 - val_acc: 0.9300
# Epoch 37/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0913 - acc: 0.9840 - val_loss: 0.4972 - val_acc: 0.8880
# Epoch 38/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0838 - acc: 0.9825 - val_loss: 0.4713 - val_acc: 0.8980
# Epoch 39/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0764 - acc: 0.9800 - val_loss: 0.3724 - val_acc: 0.9260
# Epoch 40/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0895 - acc: 0.9805 - val_loss: 0.4425 - val_acc: 0.9100
# Epoch 41/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0510 - acc: 0.9915 - val_loss: 0.3599 - val_acc: 0.9220
# Epoch 42/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0623 - acc: 0.9860 - val_loss: 0.2990 - val_acc: 0.9300
# Epoch 43/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0740 - acc: 0.9840 - val_loss: 0.5386 - val_acc: 0.9020
# Epoch 44/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0674 - acc: 0.9825 - val_loss: 0.3392 - val_acc: 0.9260
# Epoch 45/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0579 - acc: 0.9855 - val_loss: 0.3743 - val_acc: 0.9120
# Epoch 46/100
# Epoch 1/100
# 63/62 - 30s - loss: 0.0841 - acc: 0.9800 - val_loss: 0.4860 - val_acc: 0.8860
# Epoch 47/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0898 - acc: 0.9800 - val_loss: 0.7815 - val_acc: 0.8460
# Epoch 48/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0916 - acc: 0.9760 - val_loss: 0.3460 - val_acc: 0.9220
# Epoch 49/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0907 - acc: 0.9815 - val_loss: 0.7315 - val_acc: 0.8960
# Epoch 50/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0960 - acc: 0.9770 - val_loss: 0.3293 - val_acc: 0.9220
# Epoch 51/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0826 - acc: 0.9810 - val_loss: 0.4550 - val_acc: 0.9040
# Epoch 52/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0679 - acc: 0.9815 - val_loss: 0.4252 - val_acc: 0.9160
# Epoch 53/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0692 - acc: 0.9835 - val_loss: 0.4794 - val_acc: 0.8960
# Epoch 54/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0595 - acc: 0.9875 - val_loss: 0.6485 - val_acc: 0.8780
# Epoch 55/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0645 - acc: 0.9860 - val_loss: 0.3803 - val_acc: 0.9120
# Epoch 56/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0650 - acc: 0.9840 - val_loss: 0.3873 - val_acc: 0.9200
# Epoch 57/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0660 - acc: 0.9820 - val_loss: 0.3995 - val_acc: 0.9320
# Epoch 58/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0499 - acc: 0.9870 - val_loss: 0.4692 - val_acc: 0.9140
# Epoch 59/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0567 - acc: 0.9880 - val_loss: 0.4343 - val_acc: 0.9100
# Epoch 60/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0692 - acc: 0.9815 - val_loss: 0.4504 - val_acc: 0.9080
# Epoch 61/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0752 - acc: 0.9850 - val_loss: 0.4633 - val_acc: 0.8960
# Epoch 62/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0743 - acc: 0.9825 - val_loss: 0.3457 - val_acc: 0.9120
# Epoch 63/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0672 - acc: 0.9845 - val_loss: 0.7202 - val_acc: 0.8620
# Epoch 64/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0848 - acc: 0.9835 - val_loss: 0.5344 - val_acc: 0.8860
# Epoch 65/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0740 - acc: 0.9860 - val_loss: 0.4097 - val_acc: 0.9140
# Epoch 66/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0542 - acc: 0.9865 - val_loss: 0.4392 - val_acc: 0.9160
# Epoch 67/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0339 - acc: 0.9935 - val_loss: 0.3588 - val_acc: 0.9220
# Epoch 68/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0345 - acc: 0.9925 - val_loss: 0.4370 - val_acc: 0.9080
# Epoch 69/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0539 - acc: 0.9875 - val_loss: 0.3715 - val_acc: 0.9220
# Epoch 70/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0589 - acc: 0.9840 - val_loss: 0.3961 - val_acc: 0.9140
# Epoch 71/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0792 - acc: 0.9800 - val_loss: 0.6845 - val_acc: 0.8620
# Epoch 72/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0496 - acc: 0.9900 - val_loss: 0.4036 - val_acc: 0.9200
# Epoch 73/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0711 - acc: 0.9840 - val_loss: 0.4754 - val_acc: 0.8960
# Epoch 74/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0849 - acc: 0.9790 - val_loss: 0.4112 - val_acc: 0.9060
# Epoch 75/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0658 - acc: 0.9840 - val_loss: 0.4398 - val_acc: 0.9000
# Epoch 76/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0560 - acc: 0.9840 - val_loss: 0.5149 - val_acc: 0.9000
# Epoch 77/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0889 - acc: 0.9825 - val_loss: 0.4607 - val_acc: 0.9080
# Epoch 78/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0978 - acc: 0.9770 - val_loss: 0.4207 - val_acc: 0.9100
# Epoch 79/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0561 - acc: 0.9865 - val_loss: 0.3824 - val_acc: 0.9240
# Epoch 80/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0498 - acc: 0.9885 - val_loss: 0.3693 - val_acc: 0.9080
# Epoch 81/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0358 - acc: 0.9920 - val_loss: 0.3328 - val_acc: 0.9240
# Epoch 82/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0361 - acc: 0.9900 - val_loss: 0.4375 - val_acc: 0.9240
# Epoch 83/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0347 - acc: 0.9910 - val_loss: 0.2708 - val_acc: 0.9460
# Epoch 84/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0862 - acc: 0.9795 - val_loss: 0.6580 - val_acc: 0.8680
# Epoch 85/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0536 - acc: 0.9865 - val_loss: 0.4359 - val_acc: 0.8940
# Epoch 86/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0538 - acc: 0.9880 - val_loss: 0.5537 - val_acc: 0.8980
# Epoch 87/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0435 - acc: 0.9895 - val_loss: 0.3037 - val_acc: 0.9220
# Epoch 88/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0564 - acc: 0.9855 - val_loss: 0.4226 - val_acc: 0.9200
# Epoch 89/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0659 - acc: 0.9845 - val_loss: 0.3818 - val_acc: 0.9120
# Epoch 90/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0640 - acc: 0.9825 - val_loss: 0.3820 - val_acc: 0.9080
# Epoch 91/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0740 - acc: 0.9825 - val_loss: 0.5126 - val_acc: 0.8720
# Epoch 92/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0740 - acc: 0.9805 - val_loss: 0.2835 - val_acc: 0.9340
# Epoch 93/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0472 - acc: 0.9890 - val_loss: 0.5027 - val_acc: 0.9060
# Epoch 94/100
# Epoch 1/100
# 63/62 - 30s - loss: 0.0519 - acc: 0.9850 - val_loss: 0.4417 - val_acc: 0.9060
# Epoch 95/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0513 - acc: 0.9890 - val_loss: 0.3723 - val_acc: 0.9240
# Epoch 96/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0491 - acc: 0.9865 - val_loss: 0.4253 - val_acc: 0.9060
# Epoch 97/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0400 - acc: 0.9920 - val_loss: 0.3751 - val_acc: 0.9300
# Epoch 98/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0520 - acc: 0.9880 - val_loss: 0.3919 - val_acc: 0.9100
# Epoch 99/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0557 - acc: 0.9870 - val_loss: 0.3199 - val_acc: 0.9260
# Epoch 100/100
# Epoch 1/100
# 63/62 - 31s - loss: 0.0254 - acc: 0.9925 - val_loss: 0.3526 - val_acc: 0.9300
#
#  model_ResNet50 Memerlukan Waktu 3116.86 Detik (51.9 Menit) Dengan Menggunakan 100 Epochs

# %%
def return_name(label_arr):
  idx = np.where(label_arr == 1)
  return idx[0][0]

# %%
def plot_model_history(model_name, history, epochs):
  
  print(model_name)
  plt.figure(figsize=(15, 5))
  
  plt.subplot(1, 2 ,1)
  plt.plot(np.arange(0, len(history['acc'])), history['acc'], 'r')
  plt.plot(np.arange(1, len(history['val_acc'])+1), history['val_acc'], 'g')
  plt.xticks(np.arange(0, epochs+1, epochs/10))
  plt.title('Training Accuracy vs. Validation Accuracy')
  plt.xlabel('Jumlah Epoch')
  plt.ylabel('Accuracy')
  plt.legend(['train', 'validation'], loc='best')
  
  plt.subplot(1, 2, 2)
  plt.plot(np.arange(1, len(history['loss'])+1), history['loss'], 'r')
  plt.plot(np.arange(1, len(history['val_loss'])+1), history['val_loss'], 'g')
  plt.xticks(np.arange(0, epochs+1, epochs/10))
  plt.title('Training Loss vs. Validation Loss')
  plt.xlabel('Jumlah Epoch')
  plt.ylabel('Loss')
  plt.legend(['train', 'validation'], loc='best')
  
  
  plt.show()

# %%
plot_model_history('model_ResNet50', model_ResNet50_info.history, epochs)
# Out:
# model_ResNet50

# %%
model_ResNet50.save('drive/My Drive/test fish/ResNet50/256/ResNet50_100_epochs.h5')

# %%
# !unzip -q "drive/My Drive/test fish/datauji.zip"

# %%
def predict_one_image(img, model):
  img = cv2.resize(img, (img_width, img_height), interpolation = cv2.INTER_CUBIC)
  img = np.reshape(img, (1, img_width, img_height, 3))
  img = img/255.
  pred = model.predict(img)
  class_num = np.argmax(pred)
  return class_num, np.max(pred)

# %%
start = time.time()

test_img = cv2.imread('datauji/anthias/1.jpg')
pred, _ = predict_one_image(test_img, model_ResNet50)
print('Prediksi Ikan : %s %%' % (categories[pred]))
# print('Ciri-ciri : %s %%' % (deskripsi[categories[pred]]))
_, ax = plt.subplots(1)
plt.imshow(cvtRGB(test_img))
ax.set_yticklabels([])
ax.set_xticklabels([])
plt.grid('off')
plt.show()

end = time.time()
duration = end - start

print('\n Resnet50 memerlukan waktu pengujian %0.2f Detik '%(duration))
# Out:
# Prediksi Ikan : Anthias %
#  Resnet50 memerlukan waktu pengujian 0.18 Detik

# %%
def predict_val(val_data, model):
  val_input = np.reshape(val_data, (1, img_width, img_height, 3))
  val_input = val_input/255.
  pred = model.predict(val_input)
  class_num = np.argmax(pred)
  return class_num, np.max(pred)

# %%
print("Model trained from ResNet-50")

for i in range(500):
  
    idx = np.random.randint(500)
  
    ax = plt.subplot(10,50,i+1)
    # plt.imshow(cvtRGB(val_data.astype('uint8')[idx]))
    category_idx = return_name(val_labels[idx])

    pred, prob = predict_val(val_data[idx], model_ResNet50)
    print('True: %s || Predict: %s %d%%' % (categories[category_idx], categories[pred], round(prob, 2)*100))
# Out:
# Model trained from ResNet-50
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Kerapu || Predict: Kerapu 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Mandarin || Predict: Mandarin 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Layur || Predict: Layur 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 98%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Buntal || Predict: Buntal 93%
# True: Paus Pembunuh || Predict: Paus Pembunuh 86%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Anthias || Predict: Anthias 100%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 92%
# True: Terbang || Predict: Terbang 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Kakaktua || Predict: Kakaktua 97%
# True: Buntal || Predict: Buntal 100%
# True: Layur || Predict: Layur 100%
# True: Lumba-Lumba || Predict: Paus Sirip 100%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 100%
# True: Tuna || Predict: Tuna 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Pari || Predict: Pari 99%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Kerapu || Predict: Kerapu 100%
# True: Triggerfish || Predict: Triggerfish 87%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Triggerfish || Predict: Triggerfish 97%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Buntal || Predict: Buntal 100%
# True: Marlin || Predict: Marlin 100%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Giru (Nemo) || Predict: Giru (Nemo) 100%
# True: Napoleon || Predict: Napoleon 100%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Buntal || Predict: Buntal 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Anthias || Predict: Anthias 100%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Brown Tangfish || Predict: Paus Sirip 70%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Mandarin || Predict: Mandarin 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Blackghost || Predict: Blackghost 95%
# True: Brown Tangfish || Predict: Brown Tangfish 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Bawal || Predict: Bawal 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Terbang || Predict: Terbang 100%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 76%
# True: Marlin || Predict: Marlin 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Napoleon || Predict: Napoleon 98%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 99%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Kakaktua || Predict: Napoleon 100%
# True: Mandarin || Predict: Mandarin 100%
# True: Anthias || Predict: Anthias 100%
# True: Pari || Predict: Pari 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Terbang || Predict: Terbang 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Anthias || Predict: Anthias 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Layur || Predict: Layur 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Baracuda || Predict: Baracuda 100%
# True: Kerapu || Predict: Kerapu 31%
# True: Giru (Nemo) || Predict: Giru (Nemo) 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Terbang || Predict: Terbang 100%
# True: Julung-Julung || Predict: Layur 49%
# True: Layur || Predict: Layur 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 99%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Tuna || Predict: Tuna 100%
# True: Terbang || Predict: Terbang 100%
# True: Triggerfish || Predict: Pari 36%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Baracuda || Predict: Baracuda 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 99%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Kakaktua || Predict: Kakaktua 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Terbang || Predict: Terbang 100%
# True: Belanak || Predict: Belanak 100%
# True: Kuwe Gerong || Predict: Kuwe Gerong 98%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Layur || Predict: Layur 100%
# True: Blackbar chromis || Predict: Blackbar chromis 99%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Blackbar Soldierfish || Predict: Angler Frog 85%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Kakaktua || Predict: Kakaktua 100%
# True: King Anglefish || Predict: Triggerfish 100%
# True: Buntal || Predict: Buntal 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Brown Tangfish || Predict: Brown Tangfish 94%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 99%
# True: Yellow Watchman Godies || Predict: Lemon 28%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Belanak || Predict: Belanak 100%
# True: Mandarin || Predict: Mandarin 100%
# True: Anthias || Predict: Anthias 100%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Napoleon || Predict: Paus Sirip 58%
# True: Baracuda || Predict: Baracuda 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Lemon || Predict: Lemon 100%
# True: Brown Tangfish || Predict: Brown Tangfish 100%
# True: Belanak || Predict: Belanak 100%
# True: Layur || Predict: Layur 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Bawal || Predict: Bawal 100%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Napoleon || Predict: Napoleon 100%
# True: Belanak || Predict: Belanak 72%
# True: Banggai Cardinal || Predict: Banggai Cardinal 60%
# True: Layur || Predict: Layur 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Lepu Ayam || Predict: Lepu Ayam 76%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Lumba-Lumba || Predict: Paus Sirip 100%
# True: Brown Tangfish || Predict: Brown Tangfish 100%
# True: Kakaktua || Predict: Kakaktua 97%
# True: King Anglefish || Predict: King Anglefish 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Anthias || Predict: Anthias 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Kakap-Merah || Predict: Kakap-Merah 94%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Napoleon || Predict: Napoleon 100%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Buntal || Predict: Buntal 100%
# True: Lumba-Lumba || Predict: Lumba-Lumba 100%
# True: Blackbar Soldierfish || Predict: Vanikoro Sweeper 52%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Kuwe Gerong || Predict: Bawal 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Baracuda || Predict: Baracuda 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Triggerfish || Predict: Triggerfish 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Terbang || Predict: Terbang 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Kerapu || Predict: Kerapu 91%
# True: Baracuda || Predict: Baracuda 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Triggerfish || Predict: Triggerfish 87%
# True: Kakaktua || Predict: Napoleon 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 99%
# True: Marlin || Predict: Marlin 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 91%
# True: Blackghost || Predict: Blackghost 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Baracuda || Predict: Baracuda 100%
# True: Lumba-Lumba || Predict: Lumba-Lumba 100%
# True: Pari || Predict: Pari 44%
# True: Baracuda || Predict: Baracuda 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Buntal || Predict: Buntal 100%
# True: Marlin || Predict: Marlin 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Pari || Predict: Pari 99%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Giru (Nemo) || Predict: Giru (Nemo) 88%
# True: King Anglefish || Predict: King Anglefish 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 60%
# True: Bibir Merah || Predict: Bibir Merah 98%
# True: Julung-Julung || Predict: Julung-Julung 99%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Pari || Predict: Pari 99%
# True: Mandarin || Predict: Mandarin 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Triggerfish || Predict: Tuna 68%
# True: Layur || Predict: Layur 100%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Marlin || Predict: Marlin 100%
# True: Angler Frog || Predict: Angler Frog 99%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Triggerfish || Predict: Terbang 73%
# True: Barred Thicklip || Predict: Barred Thicklip 94%
# True: Layur || Predict: Layur 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Belanak || Predict: Belanak 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Bawal || Predict: Bawal 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Belanak || Predict: Belanak 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Blackghost || Predict: Blackghost 99%
# True: Marlin || Predict: Marlin 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Layur || Predict: Layur 100%
# True: Blackghost || Predict: Blackghost 100%
# True: King Anglefish || Predict: King Anglefish 98%
# True: Pari || Predict: Pari 100%
# True: Anthias || Predict: Anthias 100%
# True: Lemon || Predict: Anthias 93%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Kakap-Merah || Predict: Kakap-Merah 94%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Bibir Merah || Predict: Bibir Merah 98%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: King Anglefish || Predict: Triggerfish 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Lemon || Predict: Lemon 100%
# True: Blackghost || Predict: Blackghost 95%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 92%
# True: Baracuda || Predict: Baracuda 100%
# True: Buntal || Predict: Buntal 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Kakaktua || Predict: Kakaktua 93%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 100%
# True: Triggerfish || Predict: Pari 36%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Buntal || Predict: Buntal 100%
# True: Marlin || Predict: Marlin 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Giru (Nemo) || Predict: Giru (Nemo) 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Buntal || Predict: Buntal 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Blackghost || Predict: Blackghost 51%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Brown Tangfish || Predict: Brown Tangfish 94%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Kakaktua || Predict: Kakaktua 100%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Angler Frog || Predict: Angler Frog 99%
# True: Brown Tangfish || Predict: Brown Tangfish 100%
# True: Terbang || Predict: Terbang 100%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Triggerfish || Predict: Terbang 73%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Layur || Predict: Layur 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Anthias || Predict: Anthias 100%
# True: Bawal || Predict: Bawal 100%
# True: Mandarin || Predict: Mandarin 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Layur || Predict: Layur 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Bawal || Predict: Paus Sirip 81%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Triggerfish || Predict: Triggerfish 87%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Belanak || Predict: Belanak 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Kuwe Gerong || Predict: Kuwe Gerong 98%
# True: Dottyback || Predict: Dottyback 100%
# True: Blackghost || Predict: Blackghost 95%
# True: Marlin || Predict: Marlin 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Paus Sirip || Predict: Paus Sirip 98%
# True: Hiu Putih || Predict: Paus Sirip 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Terbang || Predict: Terbang 100%
# True: Anthias || Predict: Anthias 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Triggerfish || Predict: Terbang 73%
# True: Rainbow || Predict: Rainbow 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Bawal || Predict: Bawal 86%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Kerapu || Predict: Kerapu 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Tuna || Predict: Tuna 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 92%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Tuna || Predict: Tuna 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Layur || Predict: Layur 100%
# True: Anthias || Predict: Anthias 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Pari || Predict: Pari 44%
# True: Belanak || Predict: Belanak 100%
# True: Mandarin || Predict: Mandarin 100%
# True: Kerapu || Predict: Paus Sirip 76%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Barred Thicklip || Predict: Barred Thicklip 94%
# True: Rainbow || Predict: Rainbow 100%
# True: Terbang || Predict: Terbang 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Kuwe Gerong || Predict: Kuwe Gerong 79%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Giru (Nemo) || Predict: Giru (Nemo) 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Terbang || Predict: Terbang 100%
# True: Pari || Predict: Pari 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Tuna || Predict: Tuna 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Lumba-Lumba || Predict: Lumba-Lumba 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Brown Tangfish || Predict: Brown Tangfish 100%
# True: Kakaktua || Predict: Kakaktua 100%
# True: Mandarin || Predict: Mandarin 100%
# True: Terbang || Predict: Terbang 100%
# True: Triggerfish || Predict: Triggerfish 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Kuwe Gerong || Predict: Kuwe Gerong 98%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Blackghost || Predict: Blackghost 95%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: King Anglefish || Predict: King Anglefish 100%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Marlin || Predict: Marlin 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Bawal || Predict: Paus Sirip 81%
# True: Kakaktua || Predict: Kakaktua 100%
# True: Baracuda || Predict: Baracuda 100%
# True: King Anglefish || Predict: King Anglefish 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Lumba-Lumba || Predict: Paus Sirip 89%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Moorish Idol || Predict: Moorish Idol 95%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Kerapu || Predict: Kerapu 55%
# True: Pari || Predict: Pari 99%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 98%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
