# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import sys
import time
import cv2
import numpy as np
from matplotlib import pyplot as plt
import os

from skimage.transform import resize
from sklearn.model_selection import train_test_split

from keras.utils.np_utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.applications import ResNet50
sys.version
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# '3.6.9 (default, Nov  7 2019, 10:44:02) \n[GCC 8.3.0]'

# %%
# !unzip -q "drive/My Drive/test fish/Dataset.zip"

# %%
categori = os.listdir(os.path.join(os.getcwd(),"Dataset"))

# %%
base_path = "Dataset"
categories = sorted(categori)

# %%
print(categories)
# Out:
# ['Angler Frog', 'Anthias', 'Banggai Cardinal', 'Baracuda', 'Barred Thicklip', 'Bawal', 'Belanak', 'Bibir Merah', 'Black Saddled Toby', 'Blackbar Soldierfish', 'Blackbar chromis', 'Blackghost', 'Blue Devil', 'Brown Tangfish', 'Buntal', 'Chelmon Rostratus', 'Chevron Butterflyfish', 'Dottyback', 'Foureye Butterflyfish', 'Giru (Nemo)', 'Hiu Paus', 'Hiu Putih', 'Indigo Hamlet', 'Julung-Julung', 'Kakaktua', 'Kakap-Merah', 'Kerapu', 'King Anglefish', 'Kuwe Gerong', 'Layur', 'Lemadeng', 'Lemon', 'Lepu Ayam', 'Lumba-Lumba', 'Mandarin', 'Marlin', 'Moorish Idol', 'Napoleon', 'Neoniphon Sammara', 'Oval Butterflyfish', 'Pari', 'Paus Pembunuh', 'Paus Sirip', 'Rainbow', 'Terbang', 'Triggerfish', 'Tuna', 'Vanikoro Sweeper', 'Yellow Tangfish', 'Yellow Watchman Godies']

# %%
fnames = []
for category in categories:
    fish_folder = os.path.join(base_path, category)
    file_names = os.listdir(fish_folder)
    full_path = [os.path.join(fish_folder, file_name) for file_name in file_names]
    fnames.append(full_path)

# %%
images = []
for names in fnames:
    one_category_images = [cv2.imread(name) for name in names if (cv2.imread(name)) is not None]
    images.append(one_category_images)

# %%
print('Jumlah Gambar Setiap Kategori:', [len(f) for f in images])
# Out:
# Jumlah Gambar Setiap Kategori: [50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50, 50]

# %%
for i,imgs in enumerate(images):
    shapes = [img.shape for img in imgs]
    widths = [shape[0] for shape in shapes]
    heights = [shape[1] for shape in shapes]
    print('%d,%d is the min shape for %s' % (np.min(widths), np.min(heights), categories[i]))
# Out:
# 169,220 is the min shape for Angler Frog
# 168,224 is the min shape for Anthias
# 146,220 is the min shape for Banggai Cardinal
# 129,200 is the min shape for Baracuda
# 77,75 is the min shape for Barred Thicklip
# 156,160 is the min shape for Bawal
# 124,275 is the min shape for Belanak
# 183,275 is the min shape for Bibir Merah
# 66,68 is the min shape for Black Saddled Toby
# 129,200 is the min shape for Blackbar Soldierfish
# 183,208 is the min shape for Blackbar chromis
# 163,250 is the min shape for Blackghost
# 160,295 is the min shape for Blue Devil
# 62,71 is the min shape for Brown Tangfish
# 184,236 is the min shape for Buntal
# 183,242 is the min shape for Chelmon Rostratus
# 120,200 is the min shape for Chevron Butterflyfish
# 145,211 is the min shape for Dottyback
# 157,168 is the min shape for Foureye Butterflyfish
# 182,183 is the min shape for Giru (Nemo)
# 229,350 is the min shape for Hiu Paus
# 165,200 is the min shape for Hiu Putih
# 140,211 is the min shape for Indigo Hamlet
# 176,259 is the min shape for Julung-Julung
# 153,200 is the min shape for Kakaktua
# 133,220 is the min shape for Kakap-Merah
# 135,200 is the min shape for Kerapu
# 180,225 is the min shape for King Anglefish
# 120,211 is the min shape for Kuwe Gerong
# 105,211 is the min shape for Layur
# 147,225 is the min shape for Lemadeng
# 155,220 is the min shape for Lemon
# 132,200 is the min shape for Lepu Ayam
# 177,265 is the min shape for Lumba-Lumba
# 160,240 is the min shape for Mandarin
# 136,227 is the min shape for Marlin
# 206,190 is the min shape for Moorish Idol
# 165,220 is the min shape for Napoleon
# 225,225 is the min shape for Neoniphon Sammara
# 154,211 is the min shape for Oval Butterflyfish
# 150,218 is the min shape for Pari
# 149,220 is the min shape for Paus Pembunuh
# 183,250 is the min shape for Paus Sirip
# 143,183 is the min shape for Rainbow
# 231,218 is the min shape for Terbang
# 165,220 is the min shape for Triggerfish
# 134,250 is the min shape for Tuna
# 88,95 is the min shape for Vanikoro Sweeper
# 160,197 is the min shape for Yellow Tangfish
# 168,183 is the min shape for Yellow Watchman Godies

# %%
def cvtRGB(img):
    return cv2.cvtColor(img.copy(), cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(15,10))
for i, imgs in enumerate(images):
    plt.subplot(10,6,i+1)
    idx = np.random.randint(len(imgs))
    plt.imshow(cvtRGB(imgs[idx]))
    plt.grid('off')
    plt.title(categories[i]+' '+str(idx))
plt.show()

# %%
img_width, img_height = 256, 256

img = images[2][2]
print(img.shape)
resized_img = resize(img, (img_width, img_height, 3))
resized_img2 = cv2.resize(img,(img_width, img_height), interpolation = cv2.INTER_CUBIC)
print(resized_img.shape)
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
plt.title('original image (BGR-channel)')
plt.grid(False)
plt.imshow(img)
plt.subplot(2,2,2)
plt.title('original image (RGB-channel)')
plt.grid(False)
plt.imshow(cvtRGB(img))
plt.subplot(2,2,3)
plt.title('resized by skimage (BGR-channel)')
plt.grid(False)
plt.imshow((resized_img))
plt.subplot(2,2,4)
plt.title('resized by opencv (RGB-channel)')
plt.grid(False)
plt.imshow(cvtRGB(resized_img2))
plt.show()
# Out:
# (600, 896, 3)
# (256, 256, 3)

# %%
resized_images = []
for i,imgs in enumerate(images):
    resized_images.append([cv2.resize(img, (img_width, img_height), interpolation = cv2.INTER_CUBIC) for img in imgs])

# %%
train_images = []
val_images = []
for imgs in resized_images:
    train, test = train_test_split(imgs, train_size=0.8, test_size=0.2)
    train_images.append(train)
    val_images.append(test)

# %%
len_train_images = [len(imgs) for imgs in train_images]
print(len_train_images)
print('Jumlah Total Data Training:', np.sum(len_train_images))
train_categories = np.zeros((np.sum(len_train_images)), dtype='uint8')
for i in range(50):
    if i is 0:
        train_categories[:len_train_images[i]] = i
    else:
        train_categories[np.sum(len_train_images[:i]):np.sum(len_train_images[:i+1])] = i
        
len_val_images = [len(imgs) for imgs in val_images]
print(len_val_images)
print('Jumlah Total Data Validation:', np.sum(len_val_images))
val_categories = np.zeros((np.sum(len_val_images)), dtype='uint8')
for i in range(50):
    if i is 0:
        val_categories[:len_val_images[i]] = i
    else:
        val_categories[np.sum(len_val_images[:i]):np.sum(len_val_images[:i+1])] = i
# Out:
# [40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40]
# Jumlah Total Data Training: 2000
# [10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10]
# Jumlah Total Data Validation: 500

# %%
tmp_train_imgs = []
tmp_val_imgs = []
for imgs in train_images:
    tmp_train_imgs += imgs
for imgs in val_images:
    tmp_val_imgs += imgs
train_images = np.array(tmp_train_imgs)
val_images = np.array(tmp_val_imgs)

# %%
print('Before converting')
print('train data:', train_images.shape)
print('train labels:', train_categories.shape)

train_data = train_images.astype('float32')
val_data = val_images.astype('float32')
train_labels = to_categorical(train_categories, len(categories))
val_labels = to_categorical(val_categories, len(categories))
print()
print('After converting')
print('train data:', train_data.shape)
print('train labels:', train_labels.shape)
# Out:
# Before converting
# train data: (2000, 256, 256, 3)
# train labels: (2000,)
#
# After converting
# train data: (2000, 256, 256, 3)
# train labels: (2000, 50)

# %%
train_data = train_data[:2000]
train_labels = train_labels[:2000]
val_data = val_data[:500]
val_labels = val_labels[:500]
print('shape of train data:', train_data.shape)
print('shape of train labels:', train_labels.shape)
print('shape of val data:', val_data.shape)
print('shape of val labels:', val_labels.shape)
# Out:
# shape of train data: (2000, 256, 256, 3)
# shape of train labels: (2000, 50)
# shape of val data: (500, 256, 256, 3)
# shape of val labels: (500, 50)

# %%
def create_model_from_ResNet50():

    model = Sequential()
    model.add(ResNet50(include_top=False, pooling='avg', weights='imagenet', input_tensor=None, input_shape=(256, 256, 3)))
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(BatchNormalization())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(BatchNormalization())
    model.add(Dense(len(categories), activation='softmax'))

    optimizer = Adam(learning_rate=0.0001)
    
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])
    
    return model

# %%
model_ResNet50 = create_model_from_ResNet50()
model_ResNet50.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 3s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 2048)              8192
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                25650
# =================================================================
# Total params: 24,672,690
# Trainable params: 24,614,450
# Non-trainable params: 58,240
# _________________________________________________________________

# %%
batch_size = 32
epochs = 150

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    width_shift_range=0.4,
    height_shift_range=0.4,
    shear_range=0.2,
    zoom_range=0.3,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(
    rescale=1./255,
)


train_generator = train_datagen.flow(
    train_data,
    train_labels,
    batch_size=batch_size
)

val_generator = val_datagen.flow(
    val_data,
    val_labels,
    batch_size=batch_size
)

# %%
start = time.time()

model_ResNet50_info = model_ResNet50.fit_generator(
    generator=train_generator, 
    steps_per_epoch=len(train_data)/batch_size, 
    epochs=epochs, 
    validation_steps=len(val_data)/batch_size,
    validation_data=val_generator, 
    verbose=2
)

end = time.time()
duration = end - start
print ('\n model_ResNet50 Memerlukan Waktu %0.2f Detik (%0.1f Menit) Dengan Menggunakan %d Epochs'%(duration, duration/60, epochs) )
# Out:
# Epoch 1/150
# Epoch 1/150
# 63/62 - 64s - loss: 4.1994 - acc: 0.0525 - val_loss: 4.1633 - val_acc: 0.0200
# Epoch 2/150
# Epoch 1/150
# 63/62 - 38s - loss: 2.7194 - acc: 0.3050 - val_loss: 4.3176 - val_acc: 0.0100
# Epoch 3/150
# Epoch 1/150
# 63/62 - 40s - loss: 1.6880 - acc: 0.5785 - val_loss: 4.2099 - val_acc: 0.0240
# Epoch 4/150
# Epoch 1/150
# 63/62 - 40s - loss: 1.1085 - acc: 0.7450 - val_loss: 4.2042 - val_acc: 0.0200
# Epoch 5/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.7817 - acc: 0.8245 - val_loss: 4.2273 - val_acc: 0.0200
# Epoch 6/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.5675 - acc: 0.8735 - val_loss: 4.2221 - val_acc: 0.0280
# Epoch 7/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.4252 - acc: 0.9090 - val_loss: 4.1260 - val_acc: 0.0620
# Epoch 8/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.3653 - acc: 0.9315 - val_loss: 3.7034 - val_acc: 0.1160
# Epoch 9/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.2509 - acc: 0.9585 - val_loss: 2.8313 - val_acc: 0.2980
# Epoch 10/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.2346 - acc: 0.9560 - val_loss: 2.1883 - val_acc: 0.4480
# Epoch 11/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.1816 - acc: 0.9630 - val_loss: 1.3924 - val_acc: 0.6840
# Epoch 12/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.1976 - acc: 0.9610 - val_loss: 1.4922 - val_acc: 0.6900
# Epoch 13/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.1774 - acc: 0.9675 - val_loss: 0.6512 - val_acc: 0.8620
# Epoch 14/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.1494 - acc: 0.9735 - val_loss: 0.6530 - val_acc: 0.8440
# Epoch 15/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.1228 - acc: 0.9795 - val_loss: 0.3929 - val_acc: 0.9100
# Epoch 16/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.1175 - acc: 0.9785 - val_loss: 0.3521 - val_acc: 0.9260
# Epoch 17/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.1003 - acc: 0.9860 - val_loss: 0.2572 - val_acc: 0.9420
# Epoch 18/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0989 - acc: 0.9810 - val_loss: 0.2538 - val_acc: 0.9460
# Epoch 19/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.1050 - acc: 0.9795 - val_loss: 0.2650 - val_acc: 0.9420
# Epoch 20/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0797 - acc: 0.9860 - val_loss: 0.3097 - val_acc: 0.9420
# Epoch 21/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.1197 - acc: 0.9765 - val_loss: 0.4471 - val_acc: 0.8980
# Epoch 22/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.1425 - acc: 0.9680 - val_loss: 0.2543 - val_acc: 0.9420
# Epoch 23/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.1044 - acc: 0.9830 - val_loss: 0.2698 - val_acc: 0.9440
# Epoch 24/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.0968 - acc: 0.9785 - val_loss: 0.4542 - val_acc: 0.9120
# Epoch 25/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0979 - acc: 0.9805 - val_loss: 0.2964 - val_acc: 0.9340
# Epoch 26/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0936 - acc: 0.9815 - val_loss: 0.2631 - val_acc: 0.9360
# Epoch 27/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.0879 - acc: 0.9815 - val_loss: 0.2961 - val_acc: 0.9260
# Epoch 28/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0973 - acc: 0.9800 - val_loss: 0.3729 - val_acc: 0.9280
# Epoch 29/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0698 - acc: 0.9870 - val_loss: 0.3818 - val_acc: 0.9280
# Epoch 30/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0929 - acc: 0.9810 - val_loss: 0.2993 - val_acc: 0.9260
# Epoch 31/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.0992 - acc: 0.9775 - val_loss: 0.3528 - val_acc: 0.9220
# Epoch 32/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0915 - acc: 0.9775 - val_loss: 0.3742 - val_acc: 0.9260
# Epoch 33/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.0780 - acc: 0.9825 - val_loss: 0.4458 - val_acc: 0.9060
# Epoch 34/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.0968 - acc: 0.9770 - val_loss: 0.3457 - val_acc: 0.9080
# Epoch 35/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.0973 - acc: 0.9745 - val_loss: 0.4332 - val_acc: 0.9080
# Epoch 36/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.0849 - acc: 0.9805 - val_loss: 0.2895 - val_acc: 0.9420
# Epoch 37/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.0838 - acc: 0.9800 - val_loss: 0.5042 - val_acc: 0.8920
# Epoch 38/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.0991 - acc: 0.9760 - val_loss: 0.3368 - val_acc: 0.9260
# Epoch 39/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.1048 - acc: 0.9785 - val_loss: 0.6674 - val_acc: 0.8900
# Epoch 40/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.0960 - acc: 0.9785 - val_loss: 0.3674 - val_acc: 0.9280
# Epoch 41/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0632 - acc: 0.9865 - val_loss: 0.3611 - val_acc: 0.9340
# Epoch 42/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0590 - acc: 0.9855 - val_loss: 0.3118 - val_acc: 0.9320
# Epoch 43/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.1154 - acc: 0.9745 - val_loss: 0.5926 - val_acc: 0.8680
# Epoch 44/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.1005 - acc: 0.9755 - val_loss: 0.4550 - val_acc: 0.8980
# Epoch 45/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0707 - acc: 0.9825 - val_loss: 0.3402 - val_acc: 0.9320
# Epoch 46/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0548 - acc: 0.9870 - val_loss: 0.3221 - val_acc: 0.9400
# Epoch 47/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0369 - acc: 0.9905 - val_loss: 0.2952 - val_acc: 0.9420
# Epoch 48/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0865 - acc: 0.9800 - val_loss: 0.2579 - val_acc: 0.9380
# Epoch 49/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0733 - acc: 0.9845 - val_loss: 0.3120 - val_acc: 0.9380
# Epoch 50/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0518 - acc: 0.9890 - val_loss: 0.3164 - val_acc: 0.9300
# Epoch 51/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0535 - acc: 0.9875 - val_loss: 0.3430 - val_acc: 0.9280
# Epoch 52/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0656 - acc: 0.9855 - val_loss: 0.4891 - val_acc: 0.9200
# Epoch 53/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0910 - acc: 0.9795 - val_loss: 0.3370 - val_acc: 0.9240
# Epoch 54/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0650 - acc: 0.9830 - val_loss: 0.3668 - val_acc: 0.9280
# Epoch 55/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0655 - acc: 0.9845 - val_loss: 0.5785 - val_acc: 0.8960
# Epoch 56/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0830 - acc: 0.9775 - val_loss: 0.5770 - val_acc: 0.8940
# Epoch 57/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0794 - acc: 0.9825 - val_loss: 0.3475 - val_acc: 0.9220
# Epoch 58/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0798 - acc: 0.9790 - val_loss: 0.4411 - val_acc: 0.9180
# Epoch 59/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0587 - acc: 0.9840 - val_loss: 0.3254 - val_acc: 0.9460
# Epoch 60/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0591 - acc: 0.9860 - val_loss: 0.3636 - val_acc: 0.9360
# Epoch 61/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0588 - acc: 0.9845 - val_loss: 0.3989 - val_acc: 0.9260
# Epoch 62/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0615 - acc: 0.9860 - val_loss: 0.6008 - val_acc: 0.8920
# Epoch 63/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0589 - acc: 0.9845 - val_loss: 0.4659 - val_acc: 0.9120
# Epoch 64/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0906 - acc: 0.9790 - val_loss: 0.4797 - val_acc: 0.9040
# Epoch 65/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.1038 - acc: 0.9750 - val_loss: 0.6511 - val_acc: 0.8720
# Epoch 66/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0710 - acc: 0.9830 - val_loss: 0.7124 - val_acc: 0.8640
# Epoch 67/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0916 - acc: 0.9795 - val_loss: 0.4769 - val_acc: 0.9100
# Epoch 68/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0823 - acc: 0.9820 - val_loss: 0.4203 - val_acc: 0.9200
# Epoch 69/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0485 - acc: 0.9875 - val_loss: 0.3309 - val_acc: 0.9300
# Epoch 70/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0533 - acc: 0.9870 - val_loss: 0.4480 - val_acc: 0.9200
# Epoch 71/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0583 - acc: 0.9840 - val_loss: 0.4008 - val_acc: 0.9280
# Epoch 72/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0522 - acc: 0.9890 - val_loss: 0.3964 - val_acc: 0.9260
# Epoch 73/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0488 - acc: 0.9860 - val_loss: 0.3538 - val_acc: 0.9420
# Epoch 74/150
# Epoch 1/150
# 63/62 - 37s - loss: 0.0415 - acc: 0.9880 - val_loss: 0.4172 - val_acc: 0.9280
# Epoch 75/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0465 - acc: 0.9885 - val_loss: 0.4732 - val_acc: 0.9100
# Epoch 76/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0576 - acc: 0.9870 - val_loss: 0.3476 - val_acc: 0.9300
# Epoch 77/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0347 - acc: 0.9945 - val_loss: 0.3248 - val_acc: 0.9360
# Epoch 78/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0640 - acc: 0.9860 - val_loss: 0.4177 - val_acc: 0.9020
# Epoch 79/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0671 - acc: 0.9860 - val_loss: 0.4182 - val_acc: 0.9020
# Epoch 80/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0610 - acc: 0.9860 - val_loss: 0.3236 - val_acc: 0.9360
# Epoch 81/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0726 - acc: 0.9795 - val_loss: 0.4571 - val_acc: 0.8940
# Epoch 82/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0416 - acc: 0.9890 - val_loss: 0.3315 - val_acc: 0.9280
# Epoch 83/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0350 - acc: 0.9925 - val_loss: 0.2994 - val_acc: 0.9400
# Epoch 84/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0493 - acc: 0.9885 - val_loss: 0.4562 - val_acc: 0.9020
# Epoch 85/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0338 - acc: 0.9930 - val_loss: 0.4116 - val_acc: 0.9220
# Epoch 86/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0618 - acc: 0.9860 - val_loss: 0.3344 - val_acc: 0.9240
# Epoch 87/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0651 - acc: 0.9840 - val_loss: 0.3844 - val_acc: 0.9120
# Epoch 88/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0859 - acc: 0.9800 - val_loss: 0.4185 - val_acc: 0.9080
# Epoch 89/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.1070 - acc: 0.9765 - val_loss: 0.3205 - val_acc: 0.9280
# Epoch 90/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0438 - acc: 0.9905 - val_loss: 0.3407 - val_acc: 0.9360
# Epoch 91/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0570 - acc: 0.9830 - val_loss: 0.4399 - val_acc: 0.9160
# Epoch 92/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0477 - acc: 0.9840 - val_loss: 0.3478 - val_acc: 0.9320
# Epoch 93/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0499 - acc: 0.9875 - val_loss: 0.4646 - val_acc: 0.9080
# Epoch 94/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0504 - acc: 0.9875 - val_loss: 0.5330 - val_acc: 0.8960
# Epoch 95/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0452 - acc: 0.9885 - val_loss: 0.4559 - val_acc: 0.9220
# Epoch 96/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0495 - acc: 0.9905 - val_loss: 0.4092 - val_acc: 0.9260
# Epoch 97/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0559 - acc: 0.9870 - val_loss: 0.2911 - val_acc: 0.9360
# Epoch 98/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0340 - acc: 0.9925 - val_loss: 0.3263 - val_acc: 0.9400
# Epoch 99/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0669 - acc: 0.9840 - val_loss: 0.3906 - val_acc: 0.9260
# Epoch 100/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0463 - acc: 0.9885 - val_loss: 0.3912 - val_acc: 0.9200
# Epoch 101/150
# Epoch 1/150
# 63/62 - 41s - loss: 0.0421 - acc: 0.9880 - val_loss: 0.4464 - val_acc: 0.9140
# Epoch 102/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0528 - acc: 0.9865 - val_loss: 0.4384 - val_acc: 0.9160
# Epoch 103/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0566 - acc: 0.9860 - val_loss: 0.3142 - val_acc: 0.9340
# Epoch 104/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0448 - acc: 0.9890 - val_loss: 0.3295 - val_acc: 0.9300
# Epoch 105/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0767 - acc: 0.9845 - val_loss: 0.4547 - val_acc: 0.9040
# Epoch 106/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0665 - acc: 0.9830 - val_loss: 0.3745 - val_acc: 0.9320
# Epoch 107/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0744 - acc: 0.9835 - val_loss: 0.4501 - val_acc: 0.9180
# Epoch 108/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0491 - acc: 0.9885 - val_loss: 0.3229 - val_acc: 0.9340
# Epoch 109/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0609 - acc: 0.9840 - val_loss: 0.4125 - val_acc: 0.9220
# Epoch 110/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0522 - acc: 0.9860 - val_loss: 0.3361 - val_acc: 0.9360
# Epoch 111/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0609 - acc: 0.9840 - val_loss: 0.4223 - val_acc: 0.9260
# Epoch 112/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0556 - acc: 0.9890 - val_loss: 0.2984 - val_acc: 0.9340
# Epoch 113/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0438 - acc: 0.9885 - val_loss: 0.3123 - val_acc: 0.9380
# Epoch 114/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0393 - acc: 0.9900 - val_loss: 0.4336 - val_acc: 0.9120
# Epoch 115/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0353 - acc: 0.9900 - val_loss: 0.4239 - val_acc: 0.9140
# Epoch 116/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0344 - acc: 0.9890 - val_loss: 0.3358 - val_acc: 0.9360
# Epoch 117/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0396 - acc: 0.9895 - val_loss: 0.3260 - val_acc: 0.9340
# Epoch 118/150
# Epoch 1/150
# 63/62 - 40s - loss: 0.0394 - acc: 0.9915 - val_loss: 0.3404 - val_acc: 0.9420
# Epoch 119/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0381 - acc: 0.9890 - val_loss: 0.3469 - val_acc: 0.9360
# Epoch 120/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0297 - acc: 0.9915 - val_loss: 0.3623 - val_acc: 0.9280
# Epoch 121/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0289 - acc: 0.9900 - val_loss: 0.2580 - val_acc: 0.9440
# Epoch 122/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0270 - acc: 0.9940 - val_loss: 0.2763 - val_acc: 0.9420
# Epoch 123/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0437 - acc: 0.9900 - val_loss: 0.2516 - val_acc: 0.9300
# Epoch 124/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0327 - acc: 0.9915 - val_loss: 0.3058 - val_acc: 0.9300
# Epoch 125/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0616 - acc: 0.9835 - val_loss: 0.4170 - val_acc: 0.9060
# Epoch 126/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0721 - acc: 0.9765 - val_loss: 0.5338 - val_acc: 0.8860
# Epoch 127/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0563 - acc: 0.9850 - val_loss: 0.4145 - val_acc: 0.9000
# Epoch 128/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0501 - acc: 0.9875 - val_loss: 0.6309 - val_acc: 0.8920
# Epoch 129/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.1003 - acc: 0.9735 - val_loss: 0.4755 - val_acc: 0.9080
# Epoch 130/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0542 - acc: 0.9860 - val_loss: 0.5564 - val_acc: 0.8980
# Epoch 131/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0655 - acc: 0.9850 - val_loss: 0.4208 - val_acc: 0.9140
# Epoch 132/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0389 - acc: 0.9895 - val_loss: 0.3911 - val_acc: 0.9260
# Epoch 133/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0384 - acc: 0.9890 - val_loss: 0.3441 - val_acc: 0.9320
# Epoch 134/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0553 - acc: 0.9880 - val_loss: 0.4572 - val_acc: 0.9020
# Epoch 135/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0397 - acc: 0.9895 - val_loss: 0.3543 - val_acc: 0.9300
# Epoch 136/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0454 - acc: 0.9900 - val_loss: 0.3109 - val_acc: 0.9280
# Epoch 137/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0320 - acc: 0.9940 - val_loss: 0.3545 - val_acc: 0.9260
# Epoch 138/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0348 - acc: 0.9925 - val_loss: 0.2674 - val_acc: 0.9320
# Epoch 139/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0288 - acc: 0.9945 - val_loss: 0.2453 - val_acc: 0.9440
# Epoch 140/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0544 - acc: 0.9890 - val_loss: 0.4040 - val_acc: 0.9240
# Epoch 141/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0464 - acc: 0.9890 - val_loss: 0.3672 - val_acc: 0.9320
# Epoch 142/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0243 - acc: 0.9910 - val_loss: 0.4295 - val_acc: 0.9320
# Epoch 143/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0323 - acc: 0.9905 - val_loss: 0.5073 - val_acc: 0.9160
# Epoch 144/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0423 - acc: 0.9900 - val_loss: 0.3789 - val_acc: 0.9280
# Epoch 145/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0388 - acc: 0.9915 - val_loss: 0.6217 - val_acc: 0.9020
# Epoch 146/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0395 - acc: 0.9905 - val_loss: 0.4553 - val_acc: 0.9100
# Epoch 147/150
# Epoch 1/150
# 63/62 - 38s - loss: 0.0314 - acc: 0.9910 - val_loss: 0.4208 - val_acc: 0.9240
# Epoch 148/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0332 - acc: 0.9915 - val_loss: 0.4938 - val_acc: 0.9220
# Epoch 149/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0323 - acc: 0.9930 - val_loss: 0.4384 - val_acc: 0.9240
# Epoch 150/150
# Epoch 1/150
# 63/62 - 39s - loss: 0.0468 - acc: 0.9880 - val_loss: 0.3442 - val_acc: 0.9280
#
#  model_ResNet50 Memerlukan Waktu 5946.98 Detik (99.1 Menit) Dengan Menggunakan 150 Epochs

# %%
def return_name(label_arr):
  idx = np.where(label_arr == 1)
  return idx[0][0]

# %%
def plot_model_history(model_name, history, epochs):
  
  print(model_name)
  plt.figure(figsize=(15, 5))
  
  plt.subplot(1, 2 ,1)
  plt.plot(np.arange(0, len(history['acc'])), history['acc'], 'r')
  plt.plot(np.arange(1, len(history['val_acc'])+1), history['val_acc'], 'g')
  plt.xticks(np.arange(0, epochs+1, epochs/10))
  plt.title('Training Accuracy vs. Validation Accuracy')
  plt.xlabel('Jumlah Epoch')
  plt.ylabel('Accuracy')
  plt.legend(['train', 'validation'], loc='best')
  
  plt.subplot(1, 2, 2)
  plt.plot(np.arange(1, len(history['loss'])+1), history['loss'], 'r')
  plt.plot(np.arange(1, len(history['val_loss'])+1), history['val_loss'], 'g')
  plt.xticks(np.arange(0, epochs+1, epochs/10))
  plt.title('Training Loss vs. Validation Loss')
  plt.xlabel('Jumlah Epoch')
  plt.ylabel('Loss')
  plt.legend(['train', 'validation'], loc='best')
  
  
  plt.show()

# %%
plot_model_history('model_ResNet50', model_ResNet50_info.history, epochs)
# Out:
# model_ResNet50

# %%
model_ResNet50.save('drive/My Drive/test fish/ResNet50/256/ResNet50_150_epochs.h5')

# %%
# !unzip -q "drive/My Drive/test fish/datauji.zip"

# %%
def predict_one_image(img, model):
  img = cv2.resize(img, (img_width, img_height), interpolation = cv2.INTER_CUBIC)
  img = np.reshape(img, (1, img_width, img_height, 3))
  img = img/255.
  pred = model.predict(img)
  class_num = np.argmax(pred)
  return class_num, np.max(pred)

# %%
start = time.time()

test_img = cv2.imread('datauji/bawal/2.jpg')
pred, _ = predict_one_image(test_img, model_ResNet50)
print('Prediksi Ikan : %s %%' % (categories[pred]))
# print('Ciri-ciri : %s %%' % (deskripsi[categories[pred]]))
_, ax = plt.subplots(1)
plt.imshow(cvtRGB(test_img))
ax.set_yticklabels([])
ax.set_xticklabels([])
plt.grid('off')
plt.show()

end = time.time()
duration = end - start

print('\n Resnet50 memerlukan waktu pengujian %0.2f Detik '%(duration))
# Out:
# Prediksi Ikan : Bawal %
#  Resnet50 memerlukan waktu pengujian 0.21 Detik

# %%
def predict_val(val_data, model):
  val_input = np.reshape(val_data, (1, img_width, img_height, 3))
  val_input = val_input/255.
  pred = model.predict(val_input)
  class_num = np.argmax(pred)
  return class_num, np.max(pred)

# %%
print("Model trained from ResNet-50")

for i in range(500):
  
    idx = np.random.randint(500)
  
    ax = plt.subplot(10,50,i+1)
    # plt.imshow(cvtRGB(val_data.astype('uint8')[idx]))
    category_idx = return_name(val_labels[idx])

    pred, prob = predict_val(val_data[idx], model_ResNet50)
    print('True: %s || Predict: %s %d%%' % (categories[category_idx], categories[pred], round(prob, 2)*100))
# Out:
# Model trained from ResNet-50
# True: Triggerfish || Predict: Triggerfish 99%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Belanak || Predict: Belanak 100%
# True: Anthias || Predict: Anthias 100%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Tuna || Predict: Tuna 100%
# True: Pari || Predict: Pari 100%
# True: Brown Tangfish || Predict: Brown Tangfish 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Terbang || Predict: Lepu Ayam 99%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Lemon || Predict: Lemon 98%
# True: Dottyback || Predict: Dottyback 100%
# True: Layur || Predict: Layur 100%
# True: Blackbar chromis || Predict: Blackbar chromis 99%
# True: Kakaktua || Predict: Kakaktua 100%
# True: King Anglefish || Predict: King Anglefish 100%
# True: Angler Frog || Predict: Napoleon 23%
# True: Tuna || Predict: Tuna 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Bawal || Predict: Bawal 100%
# True: Blackbar chromis || Predict: Blackbar chromis 99%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Tuna || Predict: Tuna 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 100%
# True: Baracuda || Predict: Baracuda 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Lemon || Predict: Lemon 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Triggerfish || Predict: Triggerfish 100%
# True: Yellow Watchman Godies || Predict: Kakaktua 66%
# True: Blackghost || Predict: Blackghost 100%
# True: Triggerfish || Predict: Triggerfish 100%
# True: Layur || Predict: Layur 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Blackbar chromis || Predict: Blackbar chromis 99%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Triggerfish || Predict: Angler Frog 86%
# True: Terbang || Predict: Terbang 97%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Belanak || Predict: Belanak 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Triggerfish || Predict: Triggerfish 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Brown Tangfish || Predict: Triggerfish 28%
# True: Rainbow || Predict: Rainbow 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Kuwe Gerong || Predict: Kuwe Gerong 79%
# True: Buntal || Predict: Buntal 97%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Buntal || Predict: Buntal 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Blackbar chromis || Predict: Blackbar chromis 99%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Baracuda || Predict: Baracuda 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Giru (Nemo) || Predict: Giru (Nemo) 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Terbang || Predict: Terbang 99%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Buntal || Predict: Buntal 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Bawal || Predict: Bawal 100%
# True: Layur || Predict: Layur 100%
# True: Belanak || Predict: Belanak 100%
# True: Mandarin || Predict: Mandarin 100%
# True: Bawal || Predict: Bawal 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Napoleon || Predict: Napoleon 100%
# True: Bawal || Predict: Bawal 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Buntal || Predict: Buntal 89%
# True: Anthias || Predict: Anthias 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Triggerfish || Predict: Angler Frog 86%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Kuwe Gerong || Predict: Kuwe Gerong 79%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Belanak || Predict: Belanak 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Lumba-Lumba || Predict: Paus Pembunuh 99%
# True: Pari || Predict: Pari 100%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Marlin || Predict: Marlin 100%
# True: Napoleon || Predict: Napoleon 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Terbang || Predict: Terbang 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Tuna || Predict: Tuna 100%
# True: Lumba-Lumba || Predict: Lumba-Lumba 93%
# True: Pari || Predict: Pari 99%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Kakaktua || Predict: Kakaktua 100%
# True: Anthias || Predict: Anthias 100%
# True: Kakaktua || Predict: Kakaktua 97%
# True: Giru (Nemo) || Predict: Giru (Nemo) 100%
# True: Triggerfish || Predict: Angler Frog 86%
# True: Rainbow || Predict: Rainbow 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Moorish Idol || Predict: Moorish Idol 73%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 100%
# True: Lumba-Lumba || Predict: Hiu Putih 50%
# True: Layur || Predict: Layur 95%
# True: Moorish Idol || Predict: Moorish Idol 99%
# True: Triggerfish || Predict: Triggerfish 100%
# True: Kerapu || Predict: Kerapu 57%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 100%
# True: Belanak || Predict: Belanak 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: King Anglefish || Predict: King Anglefish 92%
# True: Giru (Nemo) || Predict: Giru (Nemo) 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Terbang || Predict: Lepu Ayam 99%
# True: Blackghost || Predict: Marlin 68%
# True: Baracuda || Predict: Baracuda 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Marlin || Predict: Marlin 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Marlin || Predict: Marlin 100%
# True: Blackbar chromis || Predict: Blackbar chromis 93%
# True: Brown Tangfish || Predict: Brown Tangfish 100%
# True: Brown Tangfish || Predict: Brown Tangfish 98%
# True: Lemon || Predict: Lemon 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Layur || Predict: Layur 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Triggerfish || Predict: Triggerfish 99%
# True: Pari || Predict: Pari 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Tuna || Predict: Tuna 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Baracuda || Predict: Baracuda 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Giru (Nemo) || Predict: Giru (Nemo) 100%
# True: Giru (Nemo) || Predict: Giru (Nemo) 100%
# True: Mandarin || Predict: Mandarin 95%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Anthias || Predict: Anthias 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Tuna || Predict: Kerapu 43%
# True: Dottyback || Predict: Dottyback 100%
# True: Terbang || Predict: Terbang 100%
# True: Layur || Predict: Layur 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Buntal || Predict: Buntal 98%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Brown Tangfish || Predict: Brown Tangfish 98%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Julung-Julung || Predict: Layur 95%
# True: Moorish Idol || Predict: Moorish Idol 73%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Lemon || Predict: Lemon 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Layur || Predict: Layur 100%
# True: Kakaktua || Predict: Kakaktua 100%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 100%
# True: Kuwe Gerong || Predict: Bawal 99%
# True: Triggerfish || Predict: Triggerfish 99%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Baracuda || Predict: Layur 75%
# True: Mandarin || Predict: Mandarin 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Kakaktua || Predict: Napoleon 100%
# True: Kakaktua || Predict: Kakaktua 100%
# True: Buntal || Predict: Buntal 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Triggerfish || Predict: Triggerfish 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Lepu Ayam || Predict: Lepu Ayam 99%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Pari || Predict: Pari 98%
# True: Baracuda || Predict: Baracuda 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Moorish Idol || Predict: Moorish Idol 99%
# True: Bawal || Predict: Bawal 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Baracuda || Predict: Baracuda 100%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Bawal || Predict: Bawal 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Lemon || Predict: Lemon 100%
# True: Lemon || Predict: Lemon 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Brown Tangfish || Predict: Brown Tangfish 100%
# True: Blackghost || Predict: Blackghost 99%
# True: Moorish Idol || Predict: Moorish Idol 99%
# True: Tuna || Predict: Tuna 100%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Blackghost || Predict: Marlin 68%
# True: Anthias || Predict: Anthias 100%
# True: Lemon || Predict: Lemon 100%
# True: Kerapu || Predict: Kerapu 100%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Triggerfish || Predict: Triggerfish 100%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Mandarin || Predict: Mandarin 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Blackghost || Predict: Blackghost 98%
# True: Angler Frog || Predict: Angler Frog 91%
# True: King Anglefish || Predict: King Anglefish 50%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Marlin || Predict: Marlin 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Bawal || Predict: Bawal 100%
# True: Brown Tangfish || Predict: Brown Tangfish 98%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Baracuda || Predict: Baracuda 100%
# True: Napoleon || Predict: Hiu Paus 81%
# True: Blackbar chromis || Predict: Blackbar chromis 99%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Anthias || Predict: Anthias 100%
# True: Belanak || Predict: Belanak 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Layur || Predict: Layur 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Mandarin || Predict: Mandarin 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Moorish Idol || Predict: Moorish Idol 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Anthias || Predict: Anthias 100%
# True: Anthias || Predict: Anthias 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Mandarin || Predict: Mandarin 100%
# True: Hiu Paus || Predict: Hiu Paus 80%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Layur || Predict: Layur 95%
# True: King Anglefish || Predict: Chevron Butterflyfish 51%
# True: Mandarin || Predict: Mandarin 86%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Paus Sirip || Predict: Paus Pembunuh 80%
# True: Pari || Predict: Pari 99%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Pari || Predict: Pari 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Layur || Predict: Layur 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Lemon || Predict: Lemon 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Lumba-Lumba || Predict: Marlin 56%
# True: Marlin || Predict: Marlin 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Marlin || Predict: Marlin 100%
# True: Kakaktua || Predict: Kakaktua 97%
# True: Tuna || Predict: Tuna 100%
# True: Dottyback || Predict: Dottyback 100%
# True: Pari || Predict: Pari 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Napoleon || Predict: Paus Sirip 88%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Blackghost || Predict: Marlin 68%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Marlin || Predict: Marlin 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Layur || Predict: Layur 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Brown Tangfish || Predict: Triggerfish 28%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: King Anglefish || Predict: King Anglefish 100%
# True: Lemon || Predict: Lemon 100%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Anthias || Predict: Anthias 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Dottyback || Predict: Dottyback 82%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Pari || Predict: Pari 100%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Blackghost || Predict: Indigo Hamlet 30%
# True: Anthias || Predict: Anthias 100%
# True: Kuwe Gerong || Predict: Belanak 67%
# True: Anthias || Predict: Anthias 100%
# True: Belanak || Predict: Belanak 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Marlin || Predict: Marlin 100%
# True: Kakap-Merah || Predict: Kakap-Merah 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 99%
# True: Lemon || Predict: Lemon 98%
# True: Napoleon || Predict: Paus Sirip 88%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Belanak || Predict: Belanak 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Blue Devil || Predict: Blue Devil 100%
# True: Buntal || Predict: Buntal 93%
# True: Terbang || Predict: Terbang 70%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 100%
# True: Belanak || Predict: Belanak 100%
# True: Giru (Nemo) || Predict: Giru (Nemo) 100%
# True: Brown Tangfish || Predict: Brown Tangfish 98%
# True: King Anglefish || Predict: King Anglefish 50%
# True: Lemon || Predict: Yellow Watchman Godies 63%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Kakaktua || Predict: Napoleon 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Marlin || Predict: Marlin 100%
# True: Baracuda || Predict: Baracuda 100%
# True: Mandarin || Predict: Mandarin 86%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Napoleon || Predict: Napoleon 100%
# True: Angler Frog || Predict: Angler Frog 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Triggerfish || Predict: Triggerfish 100%
# True: Belanak || Predict: Belanak 100%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Marlin || Predict: Marlin 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Layur || Predict: Layur 100%
# True: Tuna || Predict: Tuna 100%
# True: Hiu Putih || Predict: Hiu Putih 88%
# True: Buntal || Predict: Buntal 98%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Triggerfish || Predict: Triggerfish 100%
# True: Kerapu || Predict: Kerapu 100%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Lemon || Predict: Lemon 100%
# True: Chevron Butterflyfish || Predict: Chevron Butterflyfish 100%
# True: Lumba-Lumba || Predict: Hiu Putih 50%
# True: Tuna || Predict: Tuna 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Tuna || Predict: Kerapu 43%
# True: Paus Pembunuh || Predict: Paus Pembunuh 100%
# True: Giru (Nemo) || Predict: Giru (Nemo) 100%
# True: Belanak || Predict: Belanak 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Baracuda || Predict: Baracuda 100%
# True: Buntal || Predict: Buntal 92%
# True: Terbang || Predict: Belanak 97%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Buntal || Predict: Buntal 93%
# True: Baracuda || Predict: Lumba-Lumba 56%
# True: Vanikoro Sweeper || Predict: Vanikoro Sweeper 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Napoleon || Predict: Napoleon 100%
# True: Belanak || Predict: Belanak 100%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Pari || Predict: Pari 98%
# True: Belanak || Predict: Belanak 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Anthias || Predict: Anthias 100%
# True: Lumba-Lumba || Predict: Paus Pembunuh 99%
# True: Chelmon Rostratus || Predict: Chelmon Rostratus 100%
# True: Lumba-Lumba || Predict: Lumba-Lumba 100%
# True: Baracuda || Predict: Lumba-Lumba 56%
# True: Mandarin || Predict: Mandarin 100%
# True: Blackghost || Predict: Blackghost 99%
# True: Yellow Watchman Godies || Predict: Yellow Watchman Godies 100%
# True: Napoleon || Predict: Napoleon 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Kuwe Gerong || Predict: Belanak 93%
# True: Julung-Julung || Predict: Julung-Julung 100%
# True: Terbang || Predict: Terbang 97%
# True: Barred Thicklip || Predict: Barred Thicklip 100%
# True: Anthias || Predict: Anthias 100%
# True: Mandarin || Predict: Mandarin 100%
# True: Lemon || Predict: Lemon 100%
# True: Baracuda || Predict: Belanak 98%
# True: Lemadeng || Predict: Lemadeng 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Hiu Paus || Predict: Hiu Paus 100%
# True: Kakaktua || Predict: Kakaktua 100%
# True: Tuna || Predict: Tuna 100%
# True: Layur || Predict: Layur 100%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Baracuda || Predict: Baracuda 100%
# True: Anthias || Predict: Anthias 100%
# True: Paus Sirip || Predict: Terbang 70%
# True: Blackghost || Predict: Marlin 68%
# True: Rainbow || Predict: Rainbow 100%
# True: Triggerfish || Predict: Triggerfish 100%
# True: Bawal || Predict: Bawal 100%
# True: Belanak || Predict: Belanak 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Buntal || Predict: Buntal 85%
# True: Buntal || Predict: Buntal 93%
# True: Bibir Merah || Predict: Bibir Merah 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Lepu Ayam || Predict: Lepu Ayam 100%
# True: Blackbar chromis || Predict: Blackbar chromis 100%
# True: Indigo Hamlet || Predict: Indigo Hamlet 100%
# True: Belanak || Predict: Belanak 100%
# True: Black Saddled Toby || Predict: Black Saddled Toby 100%
# True: Neoniphon Sammara || Predict: Neoniphon Sammara 100%
# True: Oval Butterflyfish || Predict: Oval Butterflyfish 100%
# True: Hiu Putih || Predict: Hiu Putih 100%
# True: Rainbow || Predict: Rainbow 100%
# True: Bawal || Predict: Bawal 100%
# True: Mandarin || Predict: Mandarin 95%
# True: Paus Sirip || Predict: Paus Sirip 100%
# True: Lumba-Lumba || Predict: Lumba-Lumba 93%
# True: Banggai Cardinal || Predict: Banggai Cardinal 100%
# True: Blackghost || Predict: Blackghost 100%
# True: Dottyback || Predict: Dottyback 99%
# True: Yellow Tangfish || Predict: Yellow Tangfish 100%
# True: Foureye Butterflyfish || Predict: Foureye Butterflyfish 100%
# True: Tuna || Predict: Tuna 100%
# True: Brown Tangfish || Predict: Brown Tangfish 100%
# True: Blackbar Soldierfish || Predict: Blackbar Soldierfish 100%
# True: Pari || Predict: Pari 100%
